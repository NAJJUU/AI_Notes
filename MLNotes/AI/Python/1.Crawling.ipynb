# %% [markdown]
# #### requests 모듈
# 1. http request/response를 위한 모듈
# 2. HTTP method를 메서드 명으로 사용하여 request 요청(get, post)

# %%
import requests

# %% [markdown]
# #### get 요청하기
#   1. http get 요청하기
#   2. query

# %% [markdown]
# #### HTTP header 데이터 이용하기
# 1. header 데이터 구성하기
# 2. header 데이터 전달하기

# %%
url = 'http://v.daum.net/v/20230513230504827'
headers = {
    'User-Agent': 'Mozilla/5.0(Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}
resp = requests.get(url, headers=headers)
resp.text
# Out:
# '<!doctype html>\n<html class="os_window"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"> \n  <meta name="format-detection" content="telephone=no"> \n  <meta name="referrer" content="unsafe-url"> \n  <title>구글의 인공지능은 세상을 어떻게 뒤흔들까</title> \n  <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico"> \n  <meta property="mccp:docId" content="FwdAgxRyJ5"> \n  <meta property="og:site_name" content="언론사 뷰"> \n  <meta property="og:title" content="구글의 인공지능은 세상을 어떻게 뒤흔들까"> \n  <meta property="og:regDate" content="20230513230504"> \n  <meta property="og:type" content="article"> \n  <meta property="og:article:author" content="미디어오늘"> \n  <meta property="og:url" content="https://v.daum.net/v/20230513230504827"> \n  <meta property="og:image" content="https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcd
# ...

# %% [markdown]
# #### HTTP response 처리하기
# 1. response 객체
# 2. status_code 확인하기

# %%
url = 'https://v.daum.net/v/20230513230504827'
resp = requests.get(url)
if resp.status_code == 200:
  print(resp.text)
else:
  print('error')
# Out:
# <!doctype html>
# <html class="os_window">
#  <head data-cloud-area="head">
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">
#   <meta name="format-detection" content="telephone=no">
#   <meta name="referrer" content="unsafe-url">
#   <title>구글의 인공지능은 세상을 어떻게 뒤흔들까</title>
#   <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico">
#   <meta property="mccp:docId" content="FwdAgxRyJ5">
#   <meta property="og:site_name" content="언론사 뷰">
#   <meta property="og:title" content="구글의 인공지능은 세상을 어떻게 뒤흔들까">
#   <meta property="og:regDate" content="20230513230504">
#   <meta property="og:type" content="article">
#   <meta property="og:article:author" content="미디어오늘">
#   <meta property="og:url" content="https://v.daum.net/v/20230513230504827">
# ...
