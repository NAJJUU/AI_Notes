# %%
import pandas as pd

# %%
#data : https://www.kaggle.com/datasets/hesh97/titanicdataset-traincsv
train_data = pd.read_csv('./sample_data/train.csv')     # 런타임 이후에는 삭제됨 
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 새 column 추가
# - [] 사용하여 추가하기
# - insert함수 사용하여 원하는 위치에 추가하기

# %%
train_data['Age'] * 2
# Out:
# 0      44.0
# 1      76.0
# 2      52.0
# 3      70.0
# 4      70.0
#        ...
# 886    54.0
# 887    38.0
# 888     NaN
# 889    52.0
# 890    64.0
# Name: Age, Length: 891, dtype: float64

# %%
train_data['Age_double']=train_data['Age'] * 2
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double
# 0      0         A/5 21171   7.2500   NaN        S        44.0
# 1      0          PC 17599  71.2833   C85        C        76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0
# ...

# %%
train_data['Age_tripple'] = train_data['Age'] + train_data['Age_double']
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double  Age_tripple
# 0      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 1      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %%
train_data.insert(3, 'Fare10', train_data['Fare']/10)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double  Age_tripple
# 0      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 1      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %% [markdown]
# #### column 삭제하기
# - drop 함수 사용하여 삭제
#   -리스트를 사용하여 멀티플 삭제 가능

# %%
train_data.drop('Fare10', axis=1)       # 열 레벨
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.head()       # Fare10열이 안지워짐(drop을 통해 삭제할 때 새로운 복사본을 반환함)
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double  Age_tripple
# 0      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 1      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %%
train_data.drop(['Age_double', 'Age_tripple'], axis=1)
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 0              1         0       3  0.72500
# 1              2         1       1  7.12833
# 2              3         1       3  0.79250
# 3              4         1       1  5.31000
# 4              5         0       3  0.80500
# ..           ...       ...     ...      ...
# 886          887         0       2  1.30000
# 887          888         1       1  3.00000
# 888          889         0       3  2.34500
# 889          890         1       1  3.00000
# 890          891         0       3  0.77500
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
train_data.head()     # 역시 원본은 해당 컬럼이 존재함
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double  Age_tripple
# 0      0         A/5 21171   7.2500   NaN        S        44.0         66.0
# 1      0          PC 17599  71.2833   C85        C        76.0        114.0
# ...

# %%
train_data.drop(['Age_double', 'Age_tripple'], axis=1, inplace=True)      # 연산 자체를 수행함. 어떤 결과를 반환하는 것은 아님(원본에 바로 적용됨)

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 0              1         0       3  0.72500
# 1              2         1       1  7.12833
# 2              3         1       3  0.79250
# 3              4         1       1  5.31000
# 4              5         0       3  0.80500
# ..           ...       ...     ...      ...
# 886          887         0       2  1.30000
# 887          888         1       1  3.00000
# 888          889         0       3  2.34500
# 889          890         1       1  3.00000
# 890          891         0       3  0.77500
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...
